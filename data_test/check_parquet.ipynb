# %%
import pandas as pd

file_path = "D:/vin/vinfast/data_test/parquet/crawl-pages.parquet"

df = pd.read_parquet(file_path)

print(df.head())
print(df.shape)
print(df.columns)
# Out:
#                                 page_id                          crawl_job_id  \
# 0  eb90345d-4400-42ef-b09f-03bb3216f6c2  fb84213e-92f3-4556-958e-542cf661b115
# 1  3fea9183-234d-44aa-a654-5f6897e1c714  fb84213e-92f3-4556-958e-542cf661b115
# 2  0975ce87-0626-4b8d-9b8d-a84114218df0  f4117e53-fb22-4f32-96a4-fc6c45203b29
# 3  0ebed51e-cc05-477a-9c33-cde4ec4bda51  f4117e53-fb22-4f32-96a4-fc6c45203b29
# 4  205fc6a4-6292-469a-a0b7-c19ef66d12cc  f4117e53-fb22-4f32-96a4-fc6c45203b29
#
#                               source_id source_name  \
# 0  d4dc9fb6-dc93-4ec4-8bce-f432f4f193c1    Vinpearl
# 1  d4dc9fb6-dc93-4ec4-8bce-f432f4f193c1    Vinpearl
# 2  d4dc9fb6-dc93-4ec4-8bce-f432f4f193c1    Vinpearl
# 3  d4dc9fb6-dc93-4ec4-8bce-f432f4f193c1    Vinpearl
# 4  d4dc9fb6-dc93-4ec4-8bce-f432f4f193c1    Vinpearl
#
#                                                  url        domain    status  \
# 0                              https://vinpearl.com/  vinpearl.com  NEW_INFO
# ...

# %%
import pandas as pd

df = pd.read_parquet("D:/vin/vinfast/data_test/parquet/crawl-pages.parquet")

df.to_csv(
    "data.csv",
    index=False,
    encoding="utf-8-sig"
)

print("Đã chuyển Parquet sang CSV")
# Out:
# Đã chuyển Parquet sang CSV

# %%
import pandas as pd

df = pd.read_parquet("D:/vin/vinfast/data_test/parquet/crawl-pages.parquet")

df.to_json(
    "data.json",
    orient="records",
    force_ascii=False,
    indent=2
)

print("Đã chuyển sang JSON")
# Out:
# Đã chuyển sang JSON

# %%
import pandas as pd

df = pd.read_parquet("D:/vin/vinfast/data_test/parquet/crawl-pages.parquet")

df.to_excel(
    "data.xlsx",
    index=False
)

print("Đã chuyển sang Excel")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 5
#       1 import pandas as pd
#       2
#       3 df = pd.read_parquet("D:/vin/vinfast/data_test/parquet/crawl-pages.parquet")
#       4
# ----> 5 df.to_excel(
#       6     "data.xlsx",
#       7     index=False
#       8 )
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:2312, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs, autofilter)
#    2308             merge_cells=merge_cells,
#    2309             inf_rep=inf_rep,
#    2310             autofilter=autofilter,
#    2311         )
# -> 2312         formatter.write(
#    2313             excel_writer,
#    2314             sheet_name=sheet_name,
# ...
